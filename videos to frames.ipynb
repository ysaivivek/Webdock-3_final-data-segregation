# %%
# Importing all necessary libraries 
import cv2 
import os

path = "D:\\D\\university of melbourne\\Internship\\data from hard disk\\Webb Dock_Final version\\Webb Dock 3"

files = os.listdir(path)

print(files)

import glob, os
os.chdir(path)
videoFiles = []
for file in glob.glob("*.mkv"):
    videoFiles.append(file)
print("glob data:", videoFiles)

# for folders in files:
#     subfolderpath = path+'\\'+folders
#     subfiles = os.listdir(subfolderpath)
#     print(subfiles)
#     for content in subfiles:
#         folderName = content
#         while(len(folderName.split("."))==1):
            
    
#     for content in subfiles:
#         if len(content.split("."))==1:
#             rootfile = os.listdir(path+'\\'+folders)

def conversion():
    # Read the video from specified path 
    cam = cv2.VideoCapture(path) 

    try: 

        # creating a folder named data 
        if not os.path.exists('data'): 
            os.makedirs('data') 

    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data') 

    # frame 
    currentframe = 0

    while(True): 

        # reading from frame 
        ret,frame = cam.read() 

        if ret: 
            # if video is still left continue creating images 
            name = './data/frame' + str(currentframe) + '.jpg'
            print ('Creating...' + name) 

            # writing the extracted images 
            cv2.imwrite(name, frame) 

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else: 
            break

    # Release all space and windows once done 
    cam.release() 
    cv2.destroyAllWindows()
# Out:
# ['59M', '61-61 Bollard', '61-62 Slab', '61Beam', '61F', '61G', '61N', '62 Beam', '62N', '63 Beam', '63-64 Bollard', '63-64 Slab', '63E', '63F', '63G', '63N', '63N-above - Copy.mkv', '63N-above.mkv', '64 Beam', '64L', '64N', '65-66 Slab', '65N', '67M', '67N', '67N+M beam(not required)', '69 Beam', '69-70 Bollard', '69-70 Slab', '69M', '69N', '70 Beam', '70-71 wall', '70N', '71F', '71G', '71K', '71M']
# glob data: 63N-above - Copy.mkv
# glob data: 63N-above.mkv

# %%
# Importing all necessary libraries 
import cv2 
import os
from re import search

def conversion(path, opfolderName):
    # Read the video from specified path 
    cam = cv2.VideoCapture(path) 
    opFolderPath = os.path.join(os.path.split(path)[0], opfolderName)
    try:
        if not os.path.exists(opFolderPath):
            os.makedirs(opFolderPath)
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')        
    try: 
        # creating a folder named data 
        if not os.path.exists(opFolderPath + '\\data'): 
            os.makedirs('data') 
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')
    opdatafolder = os.path.join(opFolderPath + 'data')
    try: 
        # creating a folder named data 
        if not os.path.exists(opdatafolder + '\\colour'): 
            os.makedirs('colour')
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')
        
    try: 
        # creating a folder named data 
        if not os.path.exists(opdatafolder + '\\grayscale'): 
            os.makedirs('grayscale')
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')
    
#     # frame 
#     currentframe = 0

#     while(True): 

#         # reading from frame 
#         ret,frame = cam.read() 

#         if ret: 
#             # if video is still left continue creating images 
#             colourname = './data/colour/frame' + str(currentframe) + '.jpg'
#             grayscalename  = './data/grayscale/frame' + str(currentframe) + '.jpg'
#             print ('Creating...' + name) 

#             # writing the extracted images 
#             cv2.imwrite(colourname, frame) 
#             cv2.imwrite(grayscalename, cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
#             # increasing counter so that it will 
#             # show how many frames are created 
#             currentframe += 1
#         else: 
#             break

#     # Release all space and windows once done 
#     cam.release() 
#     cv2.destroyAllWindows() 


path = "D:\\D\\university of melbourne\\Internship\\Machine Learning\\test dataset\\test"
files = os.listdir(path)

print(files)

# import glob, os
# os.chdir(path)
# videoFiles = []
# for file in glob.glob("*.mkv"):
#     videoFiles.append(file)
# print("glob data:", videoFiles)
for folders in files:
    if(len(folders.split(".")) != 1):
        print("video found")
        conversion(path + "\\" + folders, folders.split(".")[0])
    else:
        subfolderpath = path+'\\'+folders
        subfiles = os.listdir(subfolderpath)
        print(folders, ":", subfiles)
#     for content in subfiles:
#         folderName = content
#         while(len(folderName.split("."))==1):
            
    
#     for content in subfiles:
#         if len(content.split("."))==1:
#             rootfile = os.listdir(path+'\\'+folders)

# %%
# Importing all necessary libraries 
import cv2 
import os
from re import search

def conversion(path, opfolderName):
    # Read the video from specified path 
    cam = cv2.VideoCapture(path) 
    opFolderPath = os.path.join(os.path.split(path)[0], opfolderName)
    print("FOldeer path:", opFolderPath)
    try:
        if not os.path.exists(opFolderPath):
            os.makedirs(opFolderPath)
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')        
    try: 
        # creating a folder named data
        dataPath = os.path.join(opFolderPath + 'data')
        if not os.path.exists(dataPath): 
            os.makedirs('data') 
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data')
#     opdatafolder = os.path.join(opFolderPath + 'data')
    try: 
        # creating a folder named data 
        colourPath = 
        if not os.path.exists(opdatafolder + '\\colour'): 
            os.makedirs('colour')
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of colour')
        
    try: 
        # creating a folder named data 
        if not os.path.exists(opdatafolder + '\\grayscale'): 
            os.makedirs('grayscale')
    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of grayscale')
    
#     # frame 
#     currentframe = 0

#     while(True): 

#         # reading from frame 
#         ret,frame = cam.read() 

#         if ret: 
#             # if video is still left continue creating images 
#             colourname = './data/colour/frame' + str(currentframe) + '.jpg'
#             grayscalename  = './data/grayscale/frame' + str(currentframe) + '.jpg'
#             print ('Creating...' + name) 

#             # writing the extracted images 
#             cv2.imwrite(colourname, frame) 
#             cv2.imwrite(grayscalename, cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
#             # increasing counter so that it will 
#             # show how many frames are created 
#             currentframe += 1
#         else: 
#             break

#     # Release all space and windows once done 
#     cam.release() 
#     cv2.destroyAllWindows() 


path = "D:\\D\\university of melbourne\\Internship\\Machine Learning\\test dataset\\test"
files = os.listdir(path)

print(files)

# import glob, os
# os.chdir(path)
# videoFiles = []
# for file in glob.glob("*.mkv"):
#     videoFiles.append(file)
# print("glob data:", videoFiles)
for folders in files:
    if(len(folders.split(".")) != 1):
        print("video found")
        conversion(path + "\\" + folders, folders.split(".")[0])
    else:
        subfolderpath = path+'\\'+folders
        subfiles = os.listdir(subfolderpath)
        print(folders, ":", subfiles)
# Out:
# ['1', '63N-above', '63N-above - Copy', 'zoom_0', 'zoom_0.mp4']
# 1 : ['2', '2_1']
# 63N-above : []
# 63N-above - Copy : []
# zoom_0 : []
# video found
# FOldeer path: D:\D\university of melbourne\Internship\Machine Learning\test dataset\test\zoom_0
# Error: Creating directory of data
# Error: Creating directory of colour
# Error: Creating directory of grayscale
